# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.26.0 to work with mlw_sdk

# %%
from azureml.core.compute import ComputeTarget
from azureml.core import Dataset, Environment

if False:
    print("Datasets:")
    [print(dataset.name) for dataset in Dataset.list(ws)]
    
    print("\nCompute Targets:")
    [print(compute.name) for compute in ComputeTarget.list(ws)]
        
    print("\nEnvironments:")
    [print(env) for env in Environment.list(ws)]

# %%
from azureml.core import RunConfiguration

#Select current environment
sklearn_env_test = Environment.get(ws,name="sklearn_env")
runconfig = RunConfiguration()
runconfig.environment = sklearn_env_test

#Select compute target
pipeline_compute = ComputeTarget(workspace=ws, name='Stand')

# %%
from azureml.core import Experiment
experiment_name = 'Pipeline_first_try'
exp_run = Experiment(workspace = ws, name = experiment_name)

# %%
#Input dataset for training
train_ds = Dataset.get_by_name(ws, "feature_selected_train_FD001")
test_ds = Dataset.get_by_name(ws, "feature_selected_test_FD001")
pipeline_path = experiment_name

# %%
from azureml.pipeline.core import Pipeline
from azureml.pipeline.steps  import PythonScriptStep
from azureml.data import OutputFileDatasetConfig

# %%
# Create a PipelineData (temporary Data Reference) for the model folder
scaled_train_ds = OutputFileDatasetConfig(name = "scaled_train_data",
                                                  destination = (ws.get_default_datastore(),
                                                                pipeline_path + "/output_datasets"))

# Step 1, scale training data
scale_train_step = PythonScriptStep(name = "Scale Training Data",
                                source_directory = '.',
                                script_name = "scale_training.py",
                                arguments = ['--input-data', train_ds.as_named_input('feature_selected_train_FD001'),
                                             '--scaled-train-data', scaled_train_ds],
                                compute_target = pipeline_compute,
                                runconfig = runconfig,
                                allow_reuse = True)

# %%
trained_model = OutputFileDatasetConfig(name = "trained_data",
                                                  destination = (ws.get_default_datastore(),
                                                                pipeline_path + "/output_models"))

# Step 2, train data
train_step = PythonScriptStep(name = "Train Data",
                                source_directory = '.',
                                script_name = "train_data.py",
                                arguments = ['--scaled-train-data', scaled_train_ds.as_input(),
                                             '--trained-data', trained_model],
                                compute_target = pipeline_compute,
                                runconfig = runconfig,
                                allow_reuse = True)

# %%
scaled_test_ds = OutputFileDatasetConfig(name = "scaled_test_data",
                                                  destination = (ws.get_default_datastore(),
                                                                pipeline_path + "/output_datasets"))

# Step 3, scale testing data
scale_test_step = PythonScriptStep(name = "Scale Testing Data",
                                source_directory = '.',
                                script_name = "scale_test.py",
                                arguments = ['--input-data', test_ds.as_named_input('feature_selected_test_FD001'),
                                             '--scaler', scaled_train_ds.as_input(),
                                             '--scaled-test-data', scaled_test_ds],
                                compute_target = pipeline_compute,
                                runconfig = runconfig,
                                allow_reuse = True)

# %%
predict_test = OutputFileDatasetConfig(name = "predict_test_data",
                                                  destination = (ws.get_default_datastore(),
                                                                pipeline_path + "/predictions"))

# Step 4, predict on test data
predict_test_step = PythonScriptStep(name = "Predict on testing data",
                                source_directory = '.',
                                script_name = "predict_test_data.py",
                                arguments = ['--scaled-test-data', scaled_test_ds.as_input(),
                                             '--trained-data', trained_model.as_input(),
                                             '--predicted-test-data', predict_test],
                                compute_target = pipeline_compute,
                                runconfig = runconfig,
                                allow_reuse = True)

# %%
steps = [scale_train_step, train_step, scale_test_step]
#, predict_test_step]

# %%
training_pipeline = Pipeline(workspace = ws, steps = steps, description = "Test")

# %%
training_pipeline_run_v1 = exp_run.submit(training_pipeline, regenerate_outputs = False)
# Out:
# Created step Scale Training Data [24eab2ac][88d67644-d67a-45b5-a3cb-5a83fa04f849], (This step will run and generate new outputs)
# Created step Train Data [1b01335b][e3aadc27-bf34-4e2e-9aff-7ed226fb1411], (This step will run and generate new outputs)
# Created step Scale Testing Data [c39e4452][c4d56844-4415-458c-b25b-4897cb641a03], (This step will run and generate new outputs)
# Submitted PipelineRun f1db20db-81c3-4e79-9d8b-458bfbcfd6e7
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/f1db20db-81c3-4e79-9d8b-458bfbcfd6e7?wsid=/subscriptions/bb345bae-e66f-461d-a1fe-67219d54a0f3/resourcegroups/rg-sandbox-kolbjorn/workspaces/mlw_sdk&tid=40cc2915-e283-4a27-9471-6bdd7ca4c6e1

# %%
from azureml.widgets import RunDetails

RunDetails(training_pipeline_run_v1).show()
training_pipeline_run_v1.wait_for_completion()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRunId: f1db20db-81c3-4e79-9d8b-458bfbcfd6e7
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/f1db20db-81c3-4e79-9d8b-458bfbcfd6e7?wsid=/subscriptions/bb345bae-e66f-461d-a1fe-67219d54a0f3/resourcegroups/rg-sandbox-kolbjorn/workspaces/mlw_sdk&tid=40cc2915-e283-4a27-9471-6bdd7ca4c6e1
# PipelineRun Status: Running
#
#
# StepRunId: 5bc5bb3b-4989-47ee-94d7-15f25aa85685
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/5bc5bb3b-4989-47ee-94d7-15f25aa85685?wsid=/subscriptions/bb345bae-e66f-461d-a1fe-67219d54a0f3/resourcegroups/rg-sandbox-kolbjorn/workspaces/mlw_sdk&tid=40cc2915-e283-4a27-9471-6bdd7ca4c6e1
# StepRun( Scale Training Data ) Status: NotStarted
# StepRun( Scale Training Data ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_034c3ef52c0cf245127515e14911d3af66c5efe9beb19622a50fbe8268d30e98_d.txt
# ========================================================================================================================
# 2021-04-30T07:14:36Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/5bc5bb3b-4989-47ee-94d7-15f25aa85685/mounts/workspaceblobstore
# 2021-04-30T07:14:37Z Starting output-watcher...
# 2021-04-30T07:14:37Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-04-30T07:14:38Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-04-30T07:14:38Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_4539de3ccb169db6707c8cade7afe14c
# Digest: sha256:a42e3315fb9cd2730a052be10a9492e8f265703745b1e8029604c5c178f93426
# Status: Image is up to date for viennaglobal.azurecr.io/azureml/azureml_4539de3ccb169db6707c8cade7afe14c:latest
# viennaglobal.azurecr.io/azureml/azureml_4539de3ccb169db6707c8cade7afe14c:latest
# 2021-04-30T07:14:40Z Check if container 5bc5bb3b-4989-47ee-94d7-15f25aa85685_sidecar already exist exited with 0,
#
# 9b7f852589448109afcf82da9e6ea44ceeb04c3967a43c29ce46aa6062b97f25
# 2021-04-30T07:14:42Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-04-30T07:14:42Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-f5d64eaca9e00ae64eb5a6fbbe2d5da4-62d254706fa9f41a-01 -sshRequired=false]
# 2021/04/30 07:14:42 Starting App Insight Logger for task:  containerSetup
# 2021/04/30 07:14:42 Version: 3.0.01573.0004 Branch: 2021-04-15 Commit: 9c5dfc4
# 2021/04/30 07:14:42 Entered ContainerSetupTask - Preparing infiniband
# 2021/04/30 07:14:42 Starting infiniband setup
# 2021/04/30 07:14:43 VMSize: standard_d3_v2, Host: ubuntu-18, Container: ubuntu-16.04
# 2021/04/30 07:14:43 VMSize: standard_d3_v2, Host: ubuntu-18, Container: ubuntu-16.04
# 2021-04-30T07:14:43Z VMSize: standard_d3_v2, Host: ubuntu-18, Container: ubuntu-16.04
# 2021/04/30 07:14:43 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/04/30 07:14:43 Not setting up Infiniband in Container
# 2021/04/30 07:14:43 Not setting up Infiniband in Container
# 2021-04-30T07:14:43Z Not setting up Infiniband in Container
# 2021/04/30 07:14:43 sshd inside container not required for job, skipping setup.
# 2021/04/30 07:14:43 All App Insights Logs was send successfully
# 2021/04/30 07:14:43 App Insight Client has already been closed
# 2021/04/30 07:14:43 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-04-30T07:14:43Z Starting docker container succeeded.
#
# Streaming azureml-logs/65_job_prep-tvmps_034c3ef52c0cf245127515e14911d3af66c5efe9beb19622a50fbe8268d30e98_d.txt
# ===============================================================================================================
# [2021-04-30T07:14:44.299474] Entering job preparation.
# [2021-04-30T07:14:47.729030] Starting job preparation.
# [2021-04-30T07:14:47.729076] Extracting the control code.
# [2021-04-30T07:14:47.745367] fetching and extracting the control code on master node.
# [2021-04-30T07:14:47.745417] Starting extract_project.
# [2021-04-30T07:14:47.745471] Starting to extract zip file.
# [2021-04-30T07:14:48.106547] Finished extracting zip file.
# [2021-04-30T07:14:48.230015] Using urllib.request Python 3.0 or later
# [2021-04-30T07:14:48.230085] Start fetching snapshots.
# [2021-04-30T07:14:48.230128] Start fetching snapshot.
# [2021-04-30T07:14:48.230149] Retrieving project from snapshot: 6127b408-fe28-4888-94f9-21961470c1a4
# Starting the daemon thread to refresh tokens in background for process with pid = 33
# [2021-04-30T07:14:48.732835] Finished fetching snapshot.
# [2021-04-30T07:14:48.732878] Finished fetching snapshots.
# [2021-04-30T07:14:48.732891] Finished extract_project.
# [2021-04-30T07:14:48.742463] Finished fetching and extracting the control code.
# [2021-04-30T07:14:48.754746] Start run_history_prep.
# [2021-04-30T07:14:48.841362] Job preparation is complete.
# [2021-04-30T07:14:48.841569] Entering Data Context Managers in Sidecar
# [2021-04-30T07:14:48.842772] Running Sidecar prep cmd...
# [2021-04-30T07:14:50.013701] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/5bc5bb3b-4989-47ee-94d7-15f25aa85685/mounts/workspaceblobstore/azureml/5bc5bb3b-4989-47ee-94d7-15f25aa85685
# [2021-04-30T07:14:50.014702] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets"]}
# [2021-04-30T07:14:50.023515] WARNING azureml.sidecar.TaskServerClient.__init__: Exception while trying to open "server_details_file": [Errno 2] No such file or directory: '/tmp/azureml/sidecar/tvmps_034c3ef52c0cf245127515e14911d3af66c5efe9beb19622a50fbe8268d30e98_d/IPC'
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.26.0 azureml-dataprep==2.14.2. Session id: 705dad46-713b-47ee-8f6a-05ee2755c1b6. Run id: 5bc5bb3b-4989-47ee-94d7-15f25aa85685.
# Processing 'scaled_train_data'.
# Mounted scaled_train_data to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/5bc5bb3b-4989-47ee-94d7-15f25aa85685/wd/tmpnia1w9iq.
# Exit __enter__ of DatasetContextManager
# Set OutputDataset scaled_train_data's target path to /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/5bc5bb3b-4989-47ee-94d7-15f25aa85685/wd/tmpnia1w9iq
# [2021-04-30T07:15:10.113281] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-04-30T07:15:10.617240] Ran Sidecar prep cmd.
# [2021-04-30T07:15:10.617339] Running Context Managers in Sidecar complete.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/04/30 07:15:13 Starting App Insight Logger for task:  runTaskLet
# 2021/04/30 07:15:13 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# 2021/04/30 07:15:13 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# [2021-04-30T07:15:14.729692] Entering context manager injector.
# 2021/04/30 07:15:18 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['scale_training.py', '--input-data', 'a0500c05-776b-42b0-bf9a-5bfae68d2011', '--scaled-train-data', 'DatasetOutputConfig:scaled_train_data'])
# Script type = None
# [2021-04-30T07:15:21.022059] Entering Run History Context Manager.
# [2021-04-30T07:15:23.151020] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/5bc5bb3b-4989-47ee-94d7-15f25aa85685/mounts/workspaceblobstore/azureml/5bc5bb3b-4989-47ee-94d7-15f25aa85685
# [2021-04-30T07:15:23.151280] Preparing to call script [scale_training.py] with arguments:['--input-data', 'a0500c05-776b-42b0-bf9a-5bfae68d2011', '--scaled-train-data', '$scaled_train_data']
# [2021-04-30T07:15:23.151376] After variable expansion, calling script [scale_training.py] with arguments:['--input-data', 'a0500c05-776b-42b0-bf9a-5bfae68d2011', '--scaled-train-data', '/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/5bc5bb3b-4989-47ee-94d7-15f25aa85685/wd/tmpnia1w9iq']
#
# Loading Data...
# Saving Data...
# Saving Scaler...
#
#
# [2021-04-30T07:15:45.566225] The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 2 items cleaning up...
# Cleanup took 0.11700654029846191 seconds
# [2021-04-30T07:15:45.903433] Finished context manager injector.
# 2021/04/30 07:15:51 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# 2021/04/30 07:15:51 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 2
# FilteredData: 0.
# 2021/04/30 07:15:51 Process Exiting with Code:  0
# 2021/04/30 07:15:51 All App Insights Logs was send successfully
#
# Streaming azureml-logs/75_job_post-tvmps_034c3ef52c0cf245127515e14911d3af66c5efe9beb19622a50fbe8268d30e98_d.txt
# ===============================================================================================================
# [2021-04-30T07:15:52.377092] Entering job release
# [2021-04-30T07:15:53.743435] Starting job release
# [2021-04-30T07:15:53.744119] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 228[2021-04-30T07:15:53.744468] job release stage : upload_datastore starting...
#
# [2021-04-30T07:15:53.747134] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-04-30T07:15:53.747282] job release stage : execute_job_release starting...
# [2021-04-30T07:15:53.747545] job release stage : copy_batchai_cached_logs starting...
# [2021-04-30T07:15:53.747701] job release stage : copy_batchai_cached_logs completed...
# [2021-04-30T07:15:53.813274] Entering context manager injector.
# [2021-04-30T07:15:53.838358] job release stage : send_run_telemetry starting...
# [2021-04-30T07:15:53.863727] job release stage : upload_datastore completed...
# [2021-04-30T07:15:53.880875] job release stage : execute_job_release completed...
# [2021-04-30T07:15:53.990631] get vm size and vm region successfully.
# [2021-04-30T07:15:54.129630] get compute meta data successfully.
# [2021-04-30T07:15:54.301583] post artifact meta request successfully.
# [2021-04-30T07:15:54.326527] upload compute record artifact successfully.
# [2021-04-30T07:15:54.326662] job release stage : send_run_telemetry completed...
# [2021-04-30T07:15:54.327075] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-04-30T07:15:54.327412] Running Sidecar release cmd...
# [2021-04-30T07:15:54.339622] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/5bc5bb3b-4989-47ee-94d7-15f25aa85685/mounts/workspaceblobstore/azureml/5bc5bb3b-4989-47ee-94d7-15f25aa85685
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/5bc5bb3b-4989-47ee-94d7-15f25aa85685/wd/tmpnia1w9iq.
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/5bc5bb3b-4989-47ee-94d7-15f25aa85685/wd/tmpnia1w9iq.
# Exit __exit__ of DatasetContextManager
# [2021-04-30T07:15:54.400398] Removing absolute paths from host...
# [2021-04-30T07:15:54.407017] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-04-30T07:15:54.902391] Ran Sidecar release cmd.
# [2021-04-30T07:15:54.902519] Job release is complete
#
# StepRun(Scale Training Data) Execution Summary
# ===============================================
# StepRun( Scale Training Data ) Status: Finished
# {'runId': '5bc5bb3b-4989-47ee-94d7-15f25aa85685', 'target': 'Stand', 'status': 'Completed', 'startTimeUtc': '2021-04-30T07:14:37.481689Z', 'endTimeUtc': '2021-04-30T07:16:05.44464Z', 'properties': {'ContentSnapshotId': '6127b408-fe28-4888-94f9-21961470c1a4', 'StepType': 'PythonScriptStep', 'azureml.moduleid': '88d67644-d67a-45b5-a3cb-5a83fa04f849', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '24eab2ac', 'azureml.pipelinerunid': 'f1db20db-81c3-4e79-9d8b-458bfbcfd6e7', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': 'a0500c05-776b-42b0-bf9a-5bfae68d2011'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'feature_selected_train_FD001', 'mechanism': 'Direct'}}], 'outputDatasets': [{'identifier': {'savedId': 'deb10686-b7ce-4ae4-9968-22c567f321b2'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'scaled_train_data'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'Pipeline_first_try/output_datasets')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "deb10686-b7ce-4ae4-9968-22c567f321b2",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='mlw_sdk', subscription_id='bb345bae-e66f-461d-a1fe-67219d54a0f3', resource_group='rg-sandbox-kolbjorn')"
#   }
# }}], 'runDefinition': {'script': 'scale_training.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--input-data', 'DatasetConsumptionConfig:feature_selected_train_FD001', '--scaled-train-data', 'DatasetOutputConfig:scaled_train_data'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'Stand', 'dataReferences': {}, 'data': {'feature_selected_train_FD001': {'dataLocation': {'dataset': {'id': 'a0500c05-776b-42b0-bf9a-5bfae68d2011', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Direct', 'environmentVariableName': 'feature_selected_train_FD001', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {'scaled_train_data': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': 'Pipeline_first_try/output_datasets'}}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}}}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'sklearn_env', 'version': '3', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.26.0']}, 'scikit-learn', 'pip', 'numpy', 'pandas', 'matplotlib'], 'name': 'azureml_612da4bfae3ad50af71004e824bf4ac8'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_034c3ef52c0cf245127515e14911d3af66c5efe9beb19622a50fbe8268d30e98_d.txt': 'https://mlwsdkstorage8e08cc56a99.blob.core.windows.net/azureml/ExperimentRun/dcid.5bc5bb3b-4989-47ee-94d7-15f25aa85685/azureml-logs/55_azureml-execution-tvmps_034c3ef52c0cf245127515e14911d3af66c5efe9beb19622a50fbe8268d30e98_d.txt?sv=2019-02-02&sr=b&sig=lIyiuHccd4HgCX4WNQA%2Bzd4tlv7%2BahUE7BwFtfYGXJM%3D&st=2021-04-30T07%3A05%3A58Z&se=2021-04-30T15%3A15%3A58Z&sp=r', 'azureml-logs/65_job_prep-tvmps_034c3ef52c0cf245127515e14911d3af66c5efe9beb19622a50fbe8268d30e98_d.txt': 'https: ...
# StepRunId: d35b40ca-f1b9-4d50-99e1-8c824c4dccd8
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8?wsid=/subscriptions/bb345bae-e66f-461d-a1fe-67219d54a0f3/resourcegroups/rg-sandbox-kolbjorn/workspaces/mlw_sdk&tid=40cc2915-e283-4a27-9471-6bdd7ca4c6e1
# StepRun( Scale Testing Data ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_034c3ef52c0cf245127515e14911d3af66c5efe9beb19622a50fbe8268d30e98_d.txt
# ========================================================================================================================
# 2021-04-30T07:16:24Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore
# 2021-04-30T07:16:24Z Starting output-watcher...
# 2021-04-30T07:16:24Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-04-30T07:16:24Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-04-30T07:16:24Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_4539de3ccb169db6707c8cade7afe14c
# Digest: sha256:a42e3315fb9cd2730a052be10a9492e8f265703745b1e8029604c5c178f93426
# Status: Image is up to date for viennaglobal.azurecr.io/azureml/azureml_4539de3ccb169db6707c8cade7afe14c:latest
# viennaglobal.azurecr.io/azureml/azureml_4539de3ccb169db6707c8cade7afe14c:latest
# 2021-04-30T07:16:25Z Check if container d35b40ca-f1b9-4d50-99e1-8c824c4dccd8_sidecar already exist exited with 0,
#
# f065c1b337b403e11c6f6f47a5f22693982abf869c79bfe208ee4bd86089ac28
# 2021-04-30T07:16:26Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-04-30T07:16:26Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-7d21e3dcbeafe20c43c63b10f2d9c0b2-e1026984904e7e04-01 -sshRequired=false]
# 2021/04/30 07:16:26 Starting App Insight Logger for task:  containerSetup
# 2021/04/30 07:16:26 Version: 3.0.01573.0004 Branch: 2021-04-15 Commit: 9c5dfc4
# 2021/04/30 07:16:26 Entered ContainerSetupTask - Preparing infiniband
# 2021/04/30 07:16:26 Starting infiniband setup
# 2021/04/30 07:16:26 VMSize: standard_d3_v2, Host: ubuntu-18, Container: ubuntu-16.04
# 2021/04/30 07:16:26 VMSize: standard_d3_v2, Host: ubuntu-18, Container: ubuntu-16.04
# 2021-04-30T07:16:26Z VMSize: standard_d3_v2, Host: ubuntu-18, Container: ubuntu-16.04
# 2021/04/30 07:16:26 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/04/30 07:16:26 Not setting up Infiniband in Container
# 2021/04/30 07:16:26 Not setting up Infiniband in Container
# 2021-04-30T07:16:26Z Not setting up Infiniband in Container
# 2021/04/30 07:16:26 sshd inside container not required for job, skipping setup.
# 2021/04/30 07:16:27 All App Insights Logs was send successfully
# 2021/04/30 07:16:27 App Insight Client has already been closed
# 2021/04/30 07:16:27 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-04-30T07:16:27Z Starting docker container succeeded.
# 2021-04-30T07:16:47Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-04-30T07:16:47Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_b2e3fe20802195ad9f35b418bb772129
# Digest: sha256:c4fc9a0725e2f72df8b2c836e583167ed01a582273fc076c0897f33137443550
# Status: Image is up to date for 63b73c7515974457821122b97a41dbd5.azurecr.io/azureml/azureml_b2e3fe20802195ad9f35b418bb772129:latest
# 63b73c7515974457821122b97a41dbd5.azurecr.io/azureml/azureml_b2e3fe20802195ad9f35b418bb772129:latest
# 2021-04-30T07:16:48Z Check if container d35b40ca-f1b9-4d50-99e1-8c824c4dccd8 already exist exited with 0, f065c1b337b4
#
#
# 2021-04-30T07:16:48Z The container d35b40ca-f1b9-4d50-99e1-8c824c4dccd8 already exists, stop and remove it before starting it.
# 2021-04-30T07:16:48Z Stopping container d35b40ca-f1b9-4d50-99e1-8c824c4dccd8 exited with 1, Error response from daemon: No such container: d35b40ca-f1b9-4d50-99e1-8c824c4dccd8
#
#
# 2021-04-30T07:16:48Z Removing container d35b40ca-f1b9-4d50-99e1-8c824c4dccd8 exited with 0, Error: No such container: d35b40ca-f1b9-4d50-99e1-8c824c4dccd8
#
#
# ca5caedc94d47a912ccbca353c37a5577174c0bb89a65b11799257af41b8de79
# 2021-04-30T07:16:48Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-04-30T07:16:48Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-7d21e3dcbeafe20c43c63b10f2d9c0b2-47916c42e300659f-01 -sshRequired=false]
# 2021/04/30 07:16:48 Starting App Insight Logger for task:  containerSetup
# 2021/04/30 07:16:48 Version: 3.0.01573.0004 Branch: 2021-04-15 Commit: 9c5dfc4
# 2021/04/30 07:16:48 Entered ContainerSetupTask - Preparing infiniband
# 2021/04/30 07:16:48 Starting infiniband setup
# 2021/04/30 07:16:48 VMSize: standard_d3_v2, Host: ubuntu-18, Container: ubuntu-16.04
# 2021/04/30 07:16:48 VMSize: standard_d3_v2, Host: ubuntu-18, Container: ubuntu-16.04
# 2021-04-30T07:16:48Z VMSize: standard_d3_v2, Host: ubuntu-18, Container: ubuntu-16.04
# 2021-04-30T07:16:48Z Not setting up Infiniband in Container
# 2021/04/30 07:16:48 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/04/30 07:16:48 Not setting up Infiniband in Container
# 2021/04/30 07:16:48 Not setting up Infiniband in Container
# 2021/04/30 07:16:48 sshd inside container not required for job, skipping setup.
# 2021/04/30 07:16:49 All App Insights Logs was send successfully
# 2021/04/30 07:16:49 App Insight Client has already been closed
# 2021/04/30 07:16:49 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-04-30T07:16:49Z Starting docker container succeeded.
# 2021-04-30T07:16:49Z Job environment preparation succeeded on 10.0.0.4. Output:
# >>>   2021/04/30 07:16:23 Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2021/04/30 07:16:23 Version: 3.0.01573.0004 Branch: 2021-04-15 Commit: 9c5dfc4
# >>>   2021/04/30 07:16:23 runtime.GOOS linux
# >>>   2021/04/30 07:16:23 Checking if '/tmp' exists
# >>>   2021/04/30 07:16:23 Reading dyanamic configs
# >>>   2021/04/30 07:16:23 Container sas url: https://baiscriptsdb3prod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=C5qYa8w7DcGiMMSKT2OPCw8bl0hKB9umyusoqUwMb%2Bk%3D
# >>>   2021/04/30 07:16:23 Failed to read from file /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables, open /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables: no such file or directory
# >>>   2021/04/30 07:16:23 [in autoUpgradeFromJobNodeSetup] Is Azsecpack installer on host: false. Is Azsecpack enabled: false,
# >>>   2021/04/30 07:16:23 Starting Azsecpack installation on machine: stand#40cc2915-e283-4a27-9471-6bdd7ca4c6e1#bb345bae-e66f-461d-a1fe-67219d54a0f3#rg-sandbox-kolbjorn#mlw_sdk#stand
# >>>   2021/04/30 07:16:23 Is Azsecpack enabled: false, GetDisableVsatlsscan: true
# >>>   2021/04/30 07:16:23 Turning off azsecpack, if it is already running
# >>>   2021/04/30 07:16:23 [doTurnOffAzsecpack] output:Unit mdsd.service could not be found.
# >>>   ,err:exit status 1.
# >>>   2021/04/30 07:16:23 OS patching disabled by dynamic configs. Skipping.
# >>>   2021/04/30 07:16:23 DetonationChamber is not enabled on this subscription: bb345bae-e66f-461d-a1fe-67219d54a0f3
# >>>   2021/04/30 07:16:23 Start to getting gpu count by running nvidia-smi command
# >>>   2021/04/30 07:16:23 GPU count found on the node: 0
# >>>   2021/04/30 07:16:23 AMLComputeXDSEndpoint:  https://db3-prodk8ds.batchai.core.windows.net
# >>>   2021/04/30 07:16:23 AMLComputeXDSApiVersion:  2018-02-01
# >>>   2021/04/30 07:16:23 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/config
# >>>   2021/04/30 07:16:23 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/wd
# >>>   2021/04/30 07:16:23 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/shared
# >>>   2021/04/30 07:16:23 From the policy service, the filtering patterns is: , data store is
# >>>   2021/04/30 07:16:23 Mounting job level file systems
# >>>   2021/04/30 07:16:23 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts
# >>>   2021/04/30 07:16:23 Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/config/.amlcompute.datastorecredentials
# >>>   2021/04/30 07:16:23 Datastore credentials file not found, skipping.
# >>>   2021/04/30 07:16:23 Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/config/.master.runtimesastokens
# >>>   2021/04/30 07:16:23 Runtime sas tokens file not found, skipping.
# >>>   2021/04/30 07:16:23 No NFS configured
# >>>   2021/04/30 07:16:23 No Azure File Shares configured
# >>>   2021/04/30 07:16:23 Mounting blob file systems
# >>>   2021/04/30 07:16:23 Blobfuse runtime version 1.3.6
# >>>   2021/04/30 07:16:23 Mounting azureml-blobstore-63b73c75-1597-4457-8211-22b97a41dbd5 container from mlwsdkstorage8e08cc56a99 account at /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore
# >>>   2021/04/30 07:16:23 Error opening env file:  open /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/config/.batchai.IdentityResponder.envlist: no such file or directory
# >>>   2021/04/30 07:16:23 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/04/30 07:16:23 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/04/30 07:16:23 Blobfuse cache size set to 185183 MB.
# >>>   2021/04/30 07:16:23 Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 --cache-size-mb=185183 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# >>>   2021/04/30 07:16:23 Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore
# >>>   2021/04/30 07:16:24 Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore
# >>>   2021/04/30 07:16:24 Successfully mounted azureml-blobstore-63b73c75-1597-4457-8211-22b97a41dbd5 container from mlwsdkstorage8e08cc56a99 account at /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore
# >>>   2021/04/30 07:16:24 No unmanaged file systems configured
# >>>   2021/04/30 07:16:24 Start to getting gpu count by running nvidia-smi command
# >>>   2021/04/30 07:16:24 From the policy service, the filtering patterns is: , data store is
# >>>   2021/04/30 07:16:24 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/azureml_compute_logs
# >>>   2021/04/30 07:16:24 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/logs
# >>>   2021/04/30 07:16:24 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/outputs
# >>>   2021/04/30 07:16:24 Starting output-watcher...
# >>>   2021/04/30 07:16:24 Single file input dataset is enabled.
# >>>   2021/04/30 07:16:24 Begin Sidecar setup
# >>>   2021/04/30 07:16:24 SingleDataDirectory enabled, Passing to Sidecar.
# >>>   2021/04/30 07:16:24 Pulling Sidecar docker image: azureml/azureml_4539de3ccb169db6707c8cade7afe14c
# >>>   2021/04/30 07:16:24 Start pull docker image: azureml
# >>>   2021/04/30 07:16:24 Getting credentials for image azureml/azureml_4539de3ccb169db6707c8cade7afe14c with url
# >>>   2021/04/30 07:16:24 Container registry is not ACR.
# >>>   2021/04/30 07:16:24 Skip getting ACR Credentials from Identity and will be getting it from EMS
# >>>   2021/04/30 07:16:24 Getting ACR Credentials from EMS for environment AzureML-Sidecar:22
# >>>   2021/04/30 07:16:24 Requesting XDS for registry details.
# >>>   2021/04/30 07:16:24 Attempt 1 of http call to https://db3-prodk8ds.batchai.core.windows.net/hosttoolapi/subscriptions/bb345bae-e66f-461d-a1fe-67219d54a0f3/resourceGroups/rg-sandbox-kolbjorn/workspaces/mlw_sdk/clusters/stand/nodes/tvmps_034c3ef52c0cf245127515e14911d3af66c5efe9beb19622a50fbe8268d30e98_d?api-version=2018-02-01
# >>>   2021/04/30 07:16:24 Got container registry details from credentials service for registry address: viennaglobal.azurecr.io.
# >>>   2021/04/30 07:16:24 Writing ACR Details to file...
# >>>   2021/04/30 07:16:24 Copying ACR Details file to worker nodes...
# >>>   2021/04/30 07:16:24 Executing 'Copy ACR Details file' on 10.0.0.4
# >>>   2021/04/30 07:16:24 Begin executing 'Copy ACR Details file' task on Node
# >>>   2021/04/30 07:16:24 'Copy ACR Details file' task Node result: succeeded
# >>>   2021/04/30 07:16:24 Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>   >>>
# >>>   >>>
# >>>   2021/04/30 07:16:25 Successfully retrieved ACR Credentials from EMS.
# >>>   2021/04/30 07:16:25 EMS returned viennaglobal.azurecr.io for environment AzureML-Sidecar
# >>>   2021/04/30 07:16:25 Updating image url from blank to viennaglobal.azurecr.io
# >>>   2021/04/30 07:16:25 Save docker credentials for image viennaglobal.azurecr.io/azureml/azureml_4539de3ccb169db6707c8cade7afe14c in /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/wd/docker_login_EBC9C488B1C40995
# >>>   2021/04/30 07:16:25 start login to the docker registry
# >>>   2021/04/30 07:16:25 Successfully logged into the docker registry.
# >>>   2021/04/30 07:16:25 Start run pull docker image command
# >>>   2021/04/30 07:16:25 Pull docker image succeeded.
# >>>   2021/04/30 07:16:25 Removed docker config dir /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/wd/docker_login_EBC9C488B1C40995
# >>>   2021/04/30 07:16:25 Pull docker image time: 741.712558ms
# >>>
# >>>   2021/04/30 07:16:25 Docker Version that this nodes use are: 20.10.5+azure
# >>>
# >>>   2021/04/30 07:16:25 Start to getting gpu count by running nvidia-smi command
# >>>   2021/04/30 07:16:25 Setting the memory limit for docker container to be 13647 MB
# >>>   2021/04/30 07:16:25 The env variable file size is 42120 bytes
# >>>   2021/04/30 07:16:25 Creating parent cgroup 'd35b40ca-f1b9-4d50-99e1-8c824c4dccd8' for Containers used in Job
# >>>   2021/04/30 07:16:25 Add parent cgroup 'd35b40ca-f1b9-4d50-99e1-8c824c4dccd8' to container 'd35b40ca-f1b9-4d50-99e1-8c824c4dccd8_sidecar'
# >>>   2021/04/30 07:16:25 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# >>>   2021/04/30 07:16:25 Original Arguments: run,--ulimit,memlock=9223372036854775807,--ulimit,nofile=262144:262144,--cap-add,sys_ptrace,--name,d35b40ca-f1b9-4d50-99e1-8c824c4dccd8_sidecar,-v,/mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts,-v,/mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs,-v,/mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared,-v,/mnt/batch/tasks/workitems/6501c3f5-8bdb-4079-a4fb-5ee3897eb0fe/job-1/d35b40ca-f1b9-4d50-9_92c14028-3a60-477a-8f1d-907e4074ce29/certs:/mnt/batch/tasks/workitems/6501c3f5-8bdb-4079-a4fb-5ee3897eb0fe/job-1/d35b40ca-f1b9-4d50-9_92c14028-3a60-477a-8f1d-907e4074ce29/certs,-v,/mnt/batch/tasks/startup:/mnt/batch/tasks/startup,-m,13647m,-v,/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/azureml_compute_logs,-v,/mnt/batch/tasks/workitems/6501c3f5-8bdb-4079-a4fb-5ee3897eb0fe/job-1/d35b40ca-f1b9-4d50-9_92c14028-3a60-477a-8f1d-907e4074ce29/wd:/mnt/batch/tasks/workitems/6501c3f5-8bdb-4079-a4fb-5ee3897eb0fe/job-1/d35b40ca-f1b9-4d50-9_92c14028-3a60-477a-8f1d-907e4074ce29/wd,-v,/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8:/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8,-v,/mnt/batch/tasks/shared/LS_root/shared/tracing/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/logs/azureml/tracing:/mnt/batch/tasks/shared/LS_root/shared/tracing/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/logs/azureml/tracing,-w,/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/wd,--expose,23,--env-file,/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/config/.batchai.envlist,--cgroup-parent=/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/,--shm-size,2g,-v,/:/mnt/hostfs:rshared,--env,SIDECAR_HOSTFS=/mnt/hostfs,--env,SIDECAR_WORKING_DIR=/mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8,--env,AZ_BATCHAI_ENVLIST_PATH=/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/config/.batchai.envlist,--env,AZUREML_SIDECAR_SINGLE_DATA_DIRECTORY=true
# >>>   2021/04/30 07:16:25 the binding /mnt/batch/tasks/shared/LS_root/shared/tracing/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/logs/azureml/tracing:/mnt/batch/tasks/shared/LS_root/shared/tracing/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/logs/azureml/tracing is discarded as we already have /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared
# >>>   2021/04/30 07:16:25 the binding /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/azureml_compute_logs is discarded as we already have /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8:/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8
# >>>   2021/04/30 07:16:25 Updated Arguments: run,--ulimit,memlock=9223372036854775807,--ulimit,nofile=262144:262144,--cap-add,sys_ptrace,--name,d35b40ca-f1b9-4d50-99e1-8c824c4dccd8_sidecar,-m,13647m,-w,/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/wd,--expose,23,--env-file,/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/config/.batchai.envlist,--cgroup-parent=/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/,--shm-size,2g,--env,SIDECAR_HOSTFS=/mnt/hostfs,--env,SIDECAR_WORKING_DIR=/mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8,--env,AZ_BATCHAI_ENVLIST_PATH=/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/config/.batchai.envlist,--env,AZUREML_SIDECAR_SINGLE_DATA_DIRECTORY=true,-v,/:/mnt/hostfs:rshared,-v,/mnt/batch/tasks/startup:/mnt/batch/tasks/startup,-v,/mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts,-v,/mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared,-v,/mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs,-v,/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8:/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8,-v,/mnt/batch/tasks/workitems/6501c3f5-8bdb-4079-a4fb-5ee3897eb0fe/job-1/d35b40ca-f1b9-4d50-9_92c14028-3a60-477a-8f1d-907e4074ce29/wd:/mnt/batch/tasks/workitems/6501c3f5-8bdb-4079-a4fb-5ee3897eb0fe/job-1/d35b40ca-f1b9-4d50-9_92c14028-3a60-477a-8f1d-907e4074ce29/wd,-v,/mnt/batch/tasks/workitems/6501c3f5-8bdb-4079-a4fb-5ee3897eb0fe/job-1/d35b40ca-f1b9-4d50-9_92c14028-3a60-477a-8f1d-907e4074ce29/certs:/mnt/batch/tasks/workitems/6501c3f5-8bdb-4079-a4fb-5ee3897eb0fe/job-1/d35b40ca-f1b9-4d50-9_92c14028-3a60-477a-8f1d-907e4074ce29/certs
# >>>   2021/04/30 07:16:25 Running Docker command: docker run --ulimit memlock=9223372036854775807 --ulimit nofile=262144:262144 --cap-add sys_ptrace --name d35b40ca-f1b9-4d50-99e1-8c824c4dccd8_sidecar -m 13647m -w /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/wd --expose 23 --env-file /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/config/.batchai.envlist --cgroup-parent=/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/ --shm-size 2g --env SIDECAR_HOSTFS=/mnt/hostfs --env SIDECAR_WORKING_DIR=/mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8 --env AZ_BATCHAI_ENVLIST_PATH=/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/config/.batchai.envlist --env AZUREML_SIDECAR_SINGLE_DATA_DIRECTORY=true -v /:/mnt/hostfs:rshared -v /mnt/batch/tasks/startup:/mnt/batch/tasks/startup -v /mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts -v /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared -v /mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs -v /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8:/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8 -v /mnt/batch/tasks/workitems/6501c3f5-8bdb-4079-a4fb-5ee3897eb0fe/job-1/d35b40ca-f1b9-4d50-9_92c14028-3a60-477a-8f1d-907e4074ce29/wd:/mnt/batch/tasks/workitems/6501c3f5-8bdb-4079-a4fb-5ee3897eb0fe/job-1/d35b40ca-f1b9-4d50-9_92c14028-3a60-477a-8f1d-907e4074ce29/wd -v /mnt/batch/tasks/workitems/6501c3f5-8bdb-4079-a4fb-5ee3897eb0fe/job-1/d35b40ca-f1b9-4d50-9_92c14028-3a60-477a-8f1d-907e4074ce29/certs:/mnt/batch/tasks/workitems/6501c3f5-8bdb-4079-a4fb-5ee3897eb0fe/job-1/d35b40ca-f1b9-4d50-9_92c14028-3a60-477a-8f1d-907e4074ce29/certs -d -it --privileged --net=host viennaglobal.azurecr.io/azureml/azureml_4539de3ccb169db6707c8cade7afe14c
# >>>   2021/04/30 07:16:25 Check if container d35b40ca-f1b9-4d50-99e1-8c824c4dccd8_sidecar already exist exited with 0,
# >>>
# >>>   2021/04/30 07:16:25 Check if container d35b40ca-f1b9-4d50-99e1-8c824c4dccd8_sidecar already exist exited with 0,
# >>>
# >>>   2021/04/30 07:16:26 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/04/30 07:16:26 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/04/30 07:16:26 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-7d21e3dcbeafe20c43c63b10f2d9c0b2-e1026984904e7e04-01 -sshRequired=false]
# >>>   2021/04/30 07:16:26 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-7d21e3dcbeafe20c43c63b10f2d9c0b2-e1026984904e7e04-01 -sshRequired=false]
# >>>   2021/04/30 07:16:27 Container ssh is not required for job type.
# >>>   2021/04/30 07:16:27 Starting docker container succeeded.
# >>>   2021/04/30 07:16:27 Starting docker container succeeded.
# >>>   2021/04/30 07:16:27 Run job preparation command in Sidecar container
# >>>   2021/04/30 07:16:27 runSpecialJobTask: checking control script content under dir: /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8-setup
# >>>   2021/04/30 07:16:27 runSpecialJobTask: control script dir content: [_vendor_jwt_decode.cpython-37.pyc: size=2231; azureml_globals.cpython-37.pyc: size=10932; context_managers.cpython-37.pyc: size=30328; log_history_status.cpython-37.pyc: size=4297; request_utilities.cpython-37.pyc: size=1380; run_token_provider.cpython-37.pyc: size=3330; _tracer.py: size=2022 md5=4c1dd974ef27d1cbec1434a93802ac73; _tracing.py: size=26407 md5=64b473943a5d2905628a9b2097f18081; _vendor_jwt_decode.py: size=2277 md5=d4b49e48ed904f03a4d6ad2f64f17368; azureml_globals.py: size=11991 md5=d7a8ea488017b4ab5f951831b16b1ccb; context_managers.py: size=45836 md5=78adcfefa8cb92ef259dbaffb7f3239e; job_prep.py: size=10845 md5=cc7071d708925a7f6215f2a06c0a0e1c; log_history_status.py: size=4428 md5=778bbe2bb6cb72340d4344366f752a63; request_utilities.py: size=1185 md5=e053daf561ffebe1c54811d9dc11beaa; run_token_provider.py: size=4228 md5=b167c8697df9c999e3676723caa93cb3; utility_context_managers.py: size=5015 md5=824d969dee21cf92733986c744d17142]
# >>>   2021/04/30 07:16:27 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/azureml_compute_logs
# >>>   2021/04/30 07:16:27 runSpecialJobTask: Raw cmd for preparation is passed is: python /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8-setup/job_prep.py --snapshots '[{"Id":"6127b408-fe28-4888-94f9-21961470c1a4","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/04/30 07:16:27 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/azureml_compute_logs/65_job_prep-tvmps_034c3ef52c0cf245127515e14911d3af66c5efe9beb19622a50fbe8268d30e98_d.txt
# >>>   2021/04/30 07:16:27 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/azureml_compute_logs/65_job_prep-tvmps_034c3ef52c0cf245127515e14911d3af66c5efe9beb19622a50fbe8268d30e98_d.txt
# >>>   2021/04/30 07:16:27 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/6501c3f5-8bdb-4079-a4fb-5ee3897eb0fe/job-1/d35b40ca-f1b9-4d50-9_92c14028-3a60-477a-8f1d-907e4074ce29/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8;python /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8-setup/job_prep.py --snapshots '[{"Id":"6127b408-fe28-4888-94f9-21961470c1a4","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/04/30 07:16:27 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/04/30 07:16:27 runSpecialJobTask: Running cmd: /usr/bin/docker exec -e AZUREML_SDK_TRACEPARENT=00-7d21e3dcbeafe20c43c63b10f2d9c0b2-70240667a2d263a9-01 -t d35b40ca-f1b9-4d50-99e1-8c824c4dccd8_sidecar bash -c source /etc/bash.bashrc; PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/6501c3f5-8bdb-4079-a4fb-5ee3897eb0fe/job-1/d35b40ca-f1b9-4d50-9_92c14028-3a60-477a-8f1d-907e4074ce29/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8;python /mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8-setup/job_prep.py --snapshots '[{"Id":"6127b408-fe28-4888-94f9-21961470c1a4","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/04/30 07:16:28 Attempt 1 of http call to https://northeurope.api.azureml.ms/history/v1.0/private/subscriptions/bb345bae-e66f-461d-a1fe-67219d54a0f3/resourceGroups/rg-sandbox-kolbjorn/providers/Microsoft.MachineLearningServices/workspaces/mlw_sdk/runs/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/spans
# >>>   2021/04/30 07:16:47 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/04/30 07:16:47 runSpecialJobTask: preparation: [2021-04-30T07:16:28.015092] Entering job preparation.
# >>>   2021/04/30 07:16:47 runSpecialJobTask: preparation: [2021-04-30T07:16:28.816456] Starting job preparation.
# >>>   2021/04/30 07:16:47 runSpecialJobTask: preparation: [2021-04-30T07:16:28.816497] Extracting the control code.
# >>>   2021/04/30 07:16:47 runSpecialJobTask: preparation: [2021-04-30T07:16:28.834555] fetching and extracting the control code on master node.
# >>>   2021/04/30 07:16:47 runSpecialJobTask: preparation: [2021-04-30T07:16:28.834605] Starting extract_project.
# >>>   2021/04/30 07:16:47 runSpecialJobTask: preparation: [2021-04-30T07:16:28.834657] Starting to extract zip file.
# >>>   2021/04/30 07:16:47 runSpecialJobTask: preparation: [2021-04-30T07:16:29.234646] Finished extracting zip file.
# >>>   2021/04/30 07:16:47 runSpecialJobTask: preparation: [2021-04-30T07:16:29.351280] Using urllib.request Python 3.0 or later
# >>>   2021/04/30 07:16:47 runSpecialJobTask: preparation: [2021-04-30T07:16:29.351342] Start fetching snapshots.
# >>>   2021/04/30 07:16:47 runSpecialJobTask: preparation: [2021-04-30T07:16:29.351381] Start fetching snapshot.
# >>>   2021/04/30 07:16:47 runSpecialJobTask: preparation: [2021-04-30T07:16:29.351399] Retrieving project from snapshot: 6127b408-fe28-4888-94f9-21961470c1a4
# >>>   2021/04/30 07:16:47 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 34
# >>>   2021/04/30 07:16:47 runSpecialJobTask: preparation: [2021-04-30T07:16:29.779330] Finished fetching snapshot.
# ...
# ===============================================================================================================
# [2021-04-30T07:17:08.572084] Entering job release
# [2021-04-30T07:17:09.935704] Starting job release
# [2021-04-30T07:17:09.936514] Logging experiment finalizing status in history service.[2021-04-30T07:17:09.936695] job release stage : upload_datastore starting...
#
# [2021-04-30T07:17:09.937032] job release stage : start importing azureml.history._tracking in run_history_release.Starting the daemon thread to refresh tokens in background for process with pid = 344
# [2021-04-30T07:17:09.937983] job release stage : copy_batchai_cached_logs starting...
#
# [2021-04-30T07:17:09.938252] job release stage : copy_batchai_cached_logs completed...
# [2021-04-30T07:17:09.938467] job release stage : execute_job_release starting...
# [2021-04-30T07:17:10.036446] job release stage : send_run_telemetry starting...
# [2021-04-30T07:17:10.073933] job release stage : execute_job_release completed...
# [2021-04-30T07:17:10.074383] Entering context manager injector.
# [2021-04-30T07:17:10.150057] job release stage : upload_datastore completed...
# [2021-04-30T07:17:10.241985] get vm size and vm region successfully.
# [2021-04-30T07:17:10.255898] get compute meta data successfully.
# [2021-04-30T07:17:10.479813] post artifact meta request successfully.
# [2021-04-30T07:17:10.504249] upload compute record artifact successfully.
# [2021-04-30T07:17:10.504355] job release stage : send_run_telemetry completed...
# [2021-04-30T07:17:10.504901] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-04-30T07:17:10.505022] Running Sidecar release cmd...
# [2021-04-30T07:17:10.517905] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/mounts/workspaceblobstore/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/wd/tmpvva5hkwa.
# fuse: failed to unmount /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/wd/tmpvva5hkwa: Invalid argument
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/wd/tmpvva5hkwa.
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/wd/tmp4ulfhxtc.
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mlw_sdk/azureml/d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/wd/tmp4ulfhxtc.
# Exit __exit__ of DatasetContextManager
# [2021-04-30T07:17:10.628190] Removing absolute paths from host...
# [2021-04-30T07:17:10.635312] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-04-30T07:17:11.311375] Ran Sidecar release cmd.
# [2021-04-30T07:17:11.311467] Job release is complete
#
# StepRun(Scale Testing Data) Execution Summary
# ==============================================
# StepRun( Scale Testing Data ) Status: Finished
# {'runId': 'd35b40ca-f1b9-4d50-99e1-8c824c4dccd8', 'target': 'Stand', 'status': 'Completed', 'startTimeUtc': '2021-04-30T07:16:24.639312Z', 'endTimeUtc': '2021-04-30T07:17:20.492946Z', 'properties': {'ContentSnapshotId': '6127b408-fe28-4888-94f9-21961470c1a4', 'StepType': 'PythonScriptStep', 'azureml.moduleid': 'c4d56844-4415-458c-b25b-4897cb641a03', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'c39e4452', 'azureml.pipelinerunid': 'f1db20db-81c3-4e79-9d8b-458bfbcfd6e7', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '2d9400f7-25fa-41b9-ace2-62a90414caba'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'feature_selected_test_FD001', 'mechanism': 'Direct'}}, {'dataset': {'id': 'deb10686-b7ce-4ae4-9968-22c567f321b2'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'input_fbc8bf91', 'mechanism': 'Mount'}}], 'outputDatasets': [{'identifier': {'savedId': 'deb10686-b7ce-4ae4-9968-22c567f321b2'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'scaled_test_data'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'Pipeline_first_try/output_datasets')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "deb10686-b7ce-4ae4-9968-22c567f321b2",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='mlw_sdk', subscription_id='bb345bae-e66f-461d-a1fe-67219d54a0f3', resource_group='rg-sandbox-kolbjorn')"
#   }
# }}], 'runDefinition': {'script': 'scale_test.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--input-data', 'DatasetConsumptionConfig:feature_selected_test_FD001', '--scaler', 'DatasetConsumptionConfig:input_fbc8bf91', '--scaled-test-data', 'DatasetOutputConfig:scaled_test_data'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'Stand', 'dataReferences': {}, 'data': {'feature_selected_test_FD001': {'dataLocation': {'dataset': {'id': '2d9400f7-25fa-41b9-ace2-62a90414caba', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Direct', 'environmentVariableName': 'feature_selected_test_FD001', 'pathOnCompute': None, 'overwrite': False}, 'input_fbc8bf91': {'dataLocation': {'dataset': {'id': 'deb10686-b7ce-4ae4-9968-22c567f321b2', 'name': None, 'version': None}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'input_fbc8bf91', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {'scaled_test_data': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': 'Pipeline_first_try/output_datasets'}}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}}}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'sklearn_env', 'version': '3', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.26.0']}, 'scikit-learn', 'pip', 'numpy', 'pandas', 'matplotlib'], 'name': 'azureml_612da4bfae3ad50af71004e824bf4ac8'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_034c3ef52c0cf245127515e14911d3af66c5efe9beb19622a50fbe8268d30e98_d.txt': 'https://mlwsdkstorage8e08cc56a99.blob.core.windows.net/azureml/ExperimentRun/dcid.d35b40ca-f1b9-4d50-99e1-8c824c4dccd8/azureml-logs/55_azureml-execution-tvmps_034c3ef52c0cf245127 ...
# StepRunId: 3f84bc75-201b-416c-b65c-562bea5918ec
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/3f84bc75-201b-416c-b65c-562bea5918ec?wsid=/subscriptions/bb345bae-e66f-461d-a1fe-67219d54a0f3/resourcegroups/rg-sandbox-kolbjorn/workspaces/mlw_sdk&tid=40cc2915-e283-4a27-9471-6bdd7ca4c6e1
#
# StepRun(Train Data) Execution Summary
# ======================================
# StepRun( Train Data ) Status: Finished
# {'runId': '3f84bc75-201b-416c-b65c-562bea5918ec', 'target': 'Stand', 'status': 'Completed', 'startTimeUtc': '2021-04-30T07:16:24.619102Z', 'endTimeUtc': '2021-04-30T07:17:14.612593Z', 'properties': {'ContentSnapshotId': '6127b408-fe28-4888-94f9-21961470c1a4', 'StepType': 'PythonScriptStep', 'azureml.moduleid': 'e3aadc27-bf34-4e2e-9aff-7ed226fb1411', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '1b01335b', 'azureml.pipelinerunid': 'f1db20db-81c3-4e79-9d8b-458bfbcfd6e7', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': 'deb10686-b7ce-4ae4-9968-22c567f321b2'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'input_bfef2f72', 'mechanism': 'Mount'}}], 'outputDatasets': [{'identifier': {'savedId': '80ea7303-f77b-4656-9367-651061f4d66f'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'trained_data'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'Pipeline_first_try/output_models')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "80ea7303-f77b-4656-9367-651061f4d66f",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='mlw_sdk', subscription_id='bb345bae-e66f-461d-a1fe-67219d54a0f3', resource_group='rg-sandbox-kolbjorn')"
#   }
# }}], 'runDefinition': {'script': 'train_data.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--scaled-train-data', 'DatasetConsumptionConfig:input_bfef2f72', '--trained-data', 'DatasetOutputConfig:trained_data'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'Stand', 'dataReferences': {}, 'data': {'input_bfef2f72': {'dataLocation': {'dataset': {'id': 'deb10686-b7ce-4ae4-9968-22c567f321b2', 'name': None, 'version': None}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'input_bfef2f72', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {'trained_data': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': 'Pipeline_first_try/output_models'}}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}}}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'sklearn_env', 'version': '3', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.26.0']}, 'scikit-learn', 'pip', 'numpy', 'pandas', 'matplotlib'], 'name': 'azureml_612da4bfae3ad50af71004e824bf4ac8'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_034c3ef52c0cf245127515e14911d3af66c5efe9beb19622a50fbe8268d30e98_d.txt': 'https://mlwsdkstorage8e08cc56a99.blob.core.windows.net/azureml/ExperimentRun/dcid.3f84bc75-201b-416c-b65c-562bea5918ec/azureml-logs/55_azureml-execution-tvmps_034c3ef52c0cf245127515e14911d3af66c5efe9beb19622a50fbe8268d30e98_d.txt?sv=2019-02-02&sr=b&sig=BRH6fKtTdef3HwcPzx2%2B7KtVRciOPTuisxfkAkNFlt0%3D&st=2021-04-30T07%3A07%3A30Z&se=2021-04-30T15%3A17%3A30Z&sp=r', 'azureml-logs/65_job_prep-tvmps_034c3ef52c0cf245127515e14911d3af66c5efe9beb19622a50fbe8268d30e98_d.txt': 'https://mlwsdkstorage8e08cc56a99.blob.core.windows.net/azureml/E ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'f1db20db-81c3-4e79-9d8b-458bfbcfd6e7', 'status': 'Completed', 'startTimeUtc': '2021-04-30T07:14:14.786949Z', 'endTimeUtc': '2021-04-30T07:17:24.455493Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlwsdkstorage8e08cc56a99.blob.core.windows.net/azureml/ExperimentRun/dcid.f1db20db-81c3-4e79-9d8b-458bfbcfd6e7/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=vPeVtRGC6980jEt1B87ok13dyYzKlxV0ggGRNSy%2FD0Y%3D&st=2021-04-30T07%3A04%3A21Z&se=2021-04-30T15%3A14%3A21Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlwsdkstorage8e08cc56a99.blob.core.windows.net/azureml/ExperimentRun/dcid.f1db20db-81c3-4e79-9d8b-458bfbcfd6e7/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=h7kWqX%2FO88fgrNn8yWIWOMoj9EeSGtvY50QVOzQOw%2FE%3D&st=2021-04-30T07%3A04%3A21Z&se=2021-04-30T15%3A14%3A21Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlwsdkstorage8e08cc56a99.blob.core.windows.net/azureml/ExperimentRun/dcid.f1db20db-81c3-4e79-9d8b-458bfbcfd6e7/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=nl%2FD9HpWGvxFwuiyO0WC2P8o5wPFhHkjmyeRGdk5C2E%3D&st=2021-04-30T07%3A04%3A21Z&se=2021-04-30T15%3A14%3A21Z&sp=r'}, 'submittedBy': 'Kolbjørn Flaarønning'}
# 'Finished'

# %%
# Publish the pipeline from the run
published_pipeline = training_pipeline_run_v1.publish_pipeline(
    name="NASA-engine-training-pipeline", description="Trains NASA Engine Prediction model", version="1.0")

published_pipeline

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
